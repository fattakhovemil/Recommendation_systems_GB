# %% [markdown]
# ## Ответьте на вопросы:

# %% [markdown]
# **Задание 1.** В чем принципиальное отличие гибридных рекомендательных систем от коллаборативной фильтрации?
#
# Приведите 2-3 примера задач, в которых необходимо использовать гибридные системы

# %% [markdown]
# **Коллаборативная фильтрация**

# %% [markdown]
# Одним из широко используемых подходов к разработке рекомендательных систем является коллаборативная  фильтрация(совместная фильтрация). Совместная фильтрация основана на предположении, что люди, которые соглашались в прошлом, согласятся в будущем, и что им понравятся предметы того же типа, что и в прошлом. Система генерирует рекомендации, используя только информацию о профилях оценок для разных пользователей или товаров. Обнаруживая одноранговых пользователей / элементы с историей рейтингов, аналогичной текущему пользователю или элементу, они генерируют рекомендации, используя это окружение. Методы совместной фильтрации подразделяются на основанные на памяти и модельные. Хорошо известным примером подходов, основанных на памяти, является алгоритм на основе пользователя, в то время как подходы на основе моделей - это Kernel-Mapping Recommender.

# %% [markdown]
# Ключевым преимуществом подхода совместной фильтрации является то, что он не полагается на контент, анализируемый машиной, и, следовательно, он способен точно рекомендовать сложные элементы, такие как фильмы, не требуя «понимания» самого элемента. Многие алгоритмы использовались для измерения сходства пользователей или элементов в рекомендательных системах. Например, подход k-nearest neighbor(k-NN) и корреляция Пирсона.

# %% [markdown]
# При построении модели на основе поведения пользователя часто делается различие между явными и неявными формами сбора данных .

# %% [markdown]
# Примеры явного сбора данных включают следующее:

# %% [markdown]
# <li>Просить пользователя оценить элемент по скользящей шкале.
# <li>Просить пользователя о поиске.
# <li>Просить пользователя оценить коллекцию элементов от избранных до наименее любимых.
# <li>Представить пользователю два предмета и попросить его выбрать лучший из них.
# <li>Попросить пользователя создать список элементов, которые ему нравятся(Классификацию Роккио или другие подобные методы).

# %% [markdown]
# Примеры неявного сбора данных включают следующее:

# %% [markdown]
# <li>Наблюдение за товарами, которые пользователь просматривает в интернет-магазине.
# <li>Анализ времени просмотра элемента / пользователя.
# <li>Ведение учета товаров, которые пользователь покупает в Интернете.
# <li>Получение списка элементов, которые пользователь слушал или смотрел на своем компьютере.
# <li>Анализируя социальную сеть пользователя и обнаруживая похожие симпатии и антипатии.

# %% [markdown]
# Подходы к совместной фильтрации часто страдают от трех проблем: холодного запуска , масштабируемости и разреженности.

# %% [markdown]
# <li><b>Холодный старт</b>: для нового пользователя или элемента недостаточно данных, чтобы давать точные рекомендации.
# <li><b>Масштабируемость</b>: во многих средах, в которых эти системы дают рекомендации, есть миллионы пользователей и продуктов. Таким образом, для расчета рекомендаций часто требуется большая вычислительная мощность.
# <li><b>Редкость</b>: количество товаров, продаваемых на крупных сайтах электронной коммерции, чрезвычайно велико. Самые активные пользователи оценили только небольшую часть всей базы данных. Таким образом, даже самые популярные товары имеют очень мало оценок.

# %% [markdown]
# Один из самых известных примеров совместной фильтрации - это совместная фильтрация по элементам (люди, которые покупают x, также покупают y), алгоритм, популяризированный системой рекомендаций Amazon.com

# %% [markdown]
# Многие социальные сети изначально использовали совместную фильтрацию, чтобы рекомендовать новых друзей, группы и другие социальные связи, исследуя сеть связей между пользователем и их друзьями. Совместная фильтрация по-прежнему используется как часть гибридных систем.

# %% [markdown]
# **Гибридные рекомендательные системы**

# %% [markdown]
# В большинстве рекомендательных систем сейчас используется гибридный подход, сочетающий совместную фильтрацию, фильтрацию на основе содержимого и другие подходы. Нет никаких причин, по которым нельзя было бы гибридизировать несколько различных техник одного типа. Гибридные подходы могут быть реализованы несколькими способами: путем раздельного прогнозирования на основе контента и на основе сотрудничества с последующим их объединением; путем добавления возможностей, основанных на содержании, к подходу, основанному на сотрудничестве(и наоборот); или путем объединения подходов в одну модель. Несколько исследований, которые эмпирически сравнивают производительность гибрида с чистыми методами совместной работы и методами, основанными на содержании, и продемонстрировали, что гибридные методы могут дать более точные рекомендации, чем чистые подходы. Эти методы также могут использоваться для преодоления некоторых общих проблем в рекомендательных системах, таких как холодный запуск и проблема разреженности, а также узкое место инженерии знаний в подходах, основанных на знаниях.

# %% [markdown]
# Netflix - хороший пример использования гибридных рекомендательных систем. Веб-сайт дает рекомендации, сравнивая привычки просмотра и поиска аналогичных пользователей(например, совместная фильтрация), а также предлагая фильмы, которые имеют общие характеристики с фильмами, получившими высокую оценку пользователя(фильтрация на основе контента).

# %% [markdown]
# Некоторые методы гибридизации включают:

# %% [markdown]
# <li><b>Взвешенный</b>: численное объединение оценок различных компонентов рекомендации.
# <li><b>Переключение</b>: выбор среди рекомендуемых компонентов и применение выбранного.
# <li><b>Смешанный</b>: рекомендации от разных рекомендателей представлены вместе, чтобы дать рекомендацию.
# <li><b>Комбинация функций</b>: функции, полученные из разных источников знаний, объединяются и передаются в единый алгоритм рекомендаций.
# <li><b>Расширение функций</b>: вычисление функции или набора функций, которые затем являются частью исходных данных для следующего метода.
# <li><b>Каскад</b>: рекомендателям отдается строгий приоритет, при этом те, которые имеют более низкий приоритет, разрывают ничью при подсчете очков с более высокими.
# <li><b>Мета-уровень</b>: применяется один метод рекомендаций и создается своего рода модель, которая затем используется в следующей технике.

# %% [markdown]
# Когда система ограничена рекомендацией контента того же типа, который уже использует пользователь, значение из системы рекомендаций значительно меньше, чем когда можно рекомендовать другие типы контента из других служб. Например, рекомендовать новостные статьи на основе просмотра новостей полезно, но было бы гораздо полезнее, если бы можно было рекомендовать музыку, видео, продукты, обсуждения и т.д. из различных служб на основе просмотра новостей. Чтобы преодолеть это, большинство рекомендательных систем, основанных на содержании, теперь используют некоторую форму гибридной системы.

# %% [markdown]
# **Задание 2.** Прочитайте статью про поиск на hh.ru https://habr.com/ru/company/hh/blog/347276/
# Нам интересна именно рекомендательная система, раздел "Производительность системы" можно пропустить
# Какие основные отличия предложенной системы от тех подходов, которые мы разбирали на семинарах? Какие проблемы могут возникнуть при выводе такой модели в продакшен?

# %% [markdown]
# Основное отличие в том, что в статье используют многоуровневый подход и при этом активно применяется a/b тестирование. Первым этапом идёт отбор кандидатов с помощью простой линейной модели(als). Вторым этапом является ранжирование XGBoost. Двухуровневая модель даёт значительный прирост метрик по сравнению с одноуровневой, функция потерь ранжирования также даёт дополнительную точность. При выводе в продакшен могут возникать сложности с нехваткой ресурсов системы, а так же со сложностью реализации, т.к. получается цепочка вычислений, каждый элемент которой может быть либо выполнен, либо нет.

# %% [markdown]
# **Задание 3.** На вебинаре мы рассматривали модель LightFM (https://making.lyst.com/lightfm/docs/lightfm.html). В работе Data Scientist'а важную часть занимает research - исследование существующих архитектур и разбор научных статей, в которых они описываются. Вам предлагается изчуть оригинальную статью про LightFM https://arxiv.org/pdf/1507.08439.pdf и ответить на следующие вопросы:

# %% [markdown]
# 1) Какой датасет используют авторы?

# %% [markdown]
# <li><b>MovieLens 10M.</b> Этот набор данных содержит 10000054 оценок и 95580 тегов, примененных к 10681 фильму 71567 пользователями онлайн-сервиса рекомендаций фильмов MovieLens.
# <li><b>CrossValidated.</b> Второй набор данных состоит из опубликованных вопросов и ответов на CrossValidated, часть более крупной сети совместных сайтов вопросов и ответов StackExchange, ориентированных на статистику и машинное обучение. Набор данных состоит из 5953 пользователей, 44 200 вопросов и 188 865 ответов и комментариев. Каждый вопрос сопровождается одним или несколькими из 1032 уникальных тегов(например, «регрессия» или «проверка гипотез»).

# %% [markdown]
# 2) Что используют в качестве признаков?

# %% [markdown]
# **Структура файла данных фильмов - MovieLens 10M.**
# <li><b>Структура файла данных рейтингов</b></li>
# Все оценки содержатся в файле ratings.dat. Каждая строка этого файла представляет собой одну оценку одного фильма одним пользователем и имеет следующий формат:
#
# UserID::MovieID::Rating::Timestamp
#
# Строки в этом файле упорядочиваются сначала по UserID, а затем внутри пользователя по MovieID.
#
# Рейтинги выставляются по пятибалльной шкале с шагом в половину звезды.
#
# Метки времени представляют собой секунды с полуночи по всемирному координированному времени (UTC) 1 января 1970 года.
#
# <li><b>Теги Структура файла данных</b></li>
#
# Все теги содержатся в файле tags.dat. Каждая строка этого файла представляет собой один тег, примененный к одному фильму одним пользователем, и имеет следующий формат:
#
# UserID::MovieID::Tag::Timestamp
#
# Строки в этом файле упорядочиваются сначала по UserID, а затем внутри пользователя по MovieID.
#
# Теги - это метаданные о фильмах, созданные пользователем. Каждый тег обычно представляет собой отдельное слово или короткую фразу. Значение, значение и назначение конкретного тега определяется каждым пользователем.
#
# Метки времени представляют собой секунды с полуночи по всемирному координированному времени (UTC) 1 января 1970 года.
#
# <li><b>Структура файла данных фильмов</b></li>
# Информация о фильме содержится в файле movies.dat. Каждая строка этого файла представляет собой один фильм и имеет следующий формат: MovieID::Title::Genres
#
# MovieID - это настоящий идентификатор MovieLens.
#
# Названия фильмов, согласно политике, следует вводить так же, как и в IMDB , включая год выпуска. Однако они вводятся вручную, поэтому могут существовать ошибки и несоответствия.
#
# Жанры представлены в списке, разделенном вертикальной чертой, и выбираются из следующих:
#
# <li>Действие
# <li>Приключение
# <li>Анимация
# <li>Детский
# <li>Комедия
# <li>Преступность
# <li>Документальный
# <li>Драма
# <li>Фантазия
# <li>Фильм-нуар
# <li>Ужастик
# <li>Музыкальный
# <li>Тайна
# <li>Романтика
# <li>Научная фантастика
# <li>Триллер
# <li>Война
# <li>Западный

# %% [markdown]
# 3) С какими моделями сравнивают LightFM? Опишите их основные идеи кратко

# %% [markdown]
# 1. MF: обычная матричная факторизационная модель с предубеждениями пользователя и элемента и сигмоидной функцией связи.
# 2. LSI-LR: модель, основанная на содержании. Чтобы оценить его, сначала извлекаются латентные темы из матрицы элементов-признаков посредством латентной семантической индексации и представляются элементы как линейные комбинации латентных тем. Затем устанавливается отдельная модель логистической регрессии(LR) для каждого пользователя в пространстве смешения тем. В отличие от модели LightFM, которая использует совместные данные для получения своего скрытого представления, LSI-LR основана исключительно на факторизации матрицы содержания. Поэтому было бы полезно подчеркнуть преимущества использования совместной информации для построения вложений объектов.
# 3. LSI-UP: гибридная модель, представляющая профили пользователей(UP) в виде линейных комбинаций векторов содержимого элементов, а затем применяет LSI к результирующей матрице для получения латентных представлений пользователя и элемента. Модель оценивается через построение матрицы userfeature: каждая строка представляет пользователя и задается суммой векторов признаков контента, представляющих элементы, с которыми пользователь положительно взаимодействовал. Затем применяется усечение SVD к нормализованной матрице, чтобы получить скрытые векторы пользователя и объекта; скрытые векторы элементов Таблица 1:
# <table border="1">
#     <caption>Результаты экспериментов</caption>
#     <tr>
#         <th></th>
#         <th colspan="2">CrossValidated</th>
#         <th colspan="2">MovieLens</th>
#     </tr>
#     <tr><td></td><td>Warm</td><td>Cold</td><td>Warm</td><td>Cold</td></tr>
#     <tr><td>LSI-LR</td><td>0.662</td><td>0.660</td><td>0.686</td><td>0.690</td></tr>
#     <tr><td>LSI-UP</td><td>0.636</td><td>0.637</td><td>0.687</td><td>0.681</td></tr>
#     <tr><td>MF</td><td>0.541</td><td>0.508</td><td>0.762</td><td>0.500</td></tr>
#     <tr><td>LightFM (tags)</td><td>0.675</td><td>0.675</td><td>0.744</td><td>0.707</td></tr>
#     <tr><td>LightFM (tags + ids)</td><td>0.682</td><td>0.674</td><td><strong>0.763</strong></td><td><strong>0.716</strong></td></tr>
#     <tr><td>LightFM (tags + about)</td><td><strong>0.695</strong></td><td><strong>0.696</strong></td><td></td><td></td></tr>
# </table>
# Результаты CrossValidated и MovieLens полученные путем проецирования их на скрытое пространство признаков. Оценка рекомендаций для пользовательского элемента таким образом, пара является внутренним продуктом их латентных представлений.
#
# 4. LightFM (tags/теги): модель LightFM использует только функции тегов.
# 5. LightFM (tags + ids/теги + ИД): в LightFM модели с помощью об тега и компоненты индикатор.
# 6. LightFM (tags + about/теги + об): модель LightFM, использующая как элемент, так и пользовательские функции. Пользовательские функции доступны только для перекрестно проверенного набора данных. Создаются через преобразование раздела "Об" профилей пользователей в представление "мешок слов". Сначала очищаются от всех HTML-тегов и неалфавитных символов, а затем преобразуются полученные строки в нижний регистр и tokenise на местах. В обоих LightFM(теги) и LightFM (теги + коды) пользователей описаны особенности индикатор. Обучаются модели LightFM с использованием стохастического градиентного спуска с начальной скоростью обучения 0,05. Скрытая размерность моделей установлена на 64 для всех моделей и экспериментов. Эта настройка предназначена для отражения баланса между точностью модели и вычислительными затратами больших векторов в производственных системах.
